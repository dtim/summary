# %%
import re
import time
import requests
import urllib.request
from bs4 import BeautifulSoup

# %%
url = "http://admoblkaluga.ru/sub/government/activity/protocol.php"

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
for link in soup.findAll('a'):
    doc_url = link.get('href')
    if doc_url and doc_url.startswith('/upload/_meropr'):
        full_url = "http://admoblkaluga.ru" + doc_url
        filename = doc_url.split('/')[-1]
        print(full_url, filename)
        urllib.request.urlretrieve(full_url, filename)
        time.sleep(1)
# Out:
# http://admoblkaluga.ru/upload/_meropr/2019/stzpr2019_07_08-138.rtf stzpr2019_07_08-138.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/przpr2019_07_08-138.rtf przpr2019_07_08-138.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/stzpr2019_06_24-137.rtf stzpr2019_06_24-137.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/przpr2019_06_24-137.rtf przpr2019_06_24-137.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/stzpr2019_06_17-136.rtf stzpr2019_06_17-136.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/przpr2019_06_17-136.rtf przpr2019_06_17-136.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/povzpr2019_06_10.rtf povzpr2019_06_10.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/stzpr2019_06_10-135.rtf stzpr2019_06_10-135.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/przpr2019_06_10-135.rtf przpr2019_06_10-135.rtf
# http://admoblkaluga.ru/upload/_meropr/2019/stzpr2019_05_27-134.rtf stzpr2019_05_27-134.rtf
# ...
